# %%
# !pip install langchain chromadb faiss-cpu openai tiktoken langchain_openai langchain-community wikipedia
# Out:
# Requirement already satisfied: langchain in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (0.3.25)
#   DEPRECATION: Building 'wikipedia' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'wikipedia'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Requirement already satisfied: chromadb in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (1.0.13)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: openai in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (1.82.1)
# Requirement already satisfied: tiktoken in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (0.9.0)
# Requirement already satisfied: langchain_openai in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (0.3.18)
# Requirement already satisfied: langchain-community in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (0.3.24)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (0.3.63)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (0.3.43)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (2.11.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: certifi in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (2.2.6)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-community) (3.12.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from wikipedia) (4.13.4)
# Requirement already satisfied: pyproject_hooks in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from build>=1.0.3->chromadb) (2.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.32.3)
# Requirement already satisfied: filelock in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from beautifulsoup4->wikipedia) (2.7)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\harshika.pathak\appdata\local\miniconda3\envs\langchain_env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading faiss_cpu-1.11.0-cp310-cp310-win_amd64.whl (15.0 MB)
#    ---------------------------------------- 0.0/15.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.8/15.0 MB 10.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/15.0 MB 11.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.6/15.0 MB 11.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.9/15.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------ --------- 11.3/15.0 MB 11.2 MB/s eta 0:00:01
#    ------------------------------------- -- 13.9/15.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  14.9/15.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 15.0/15.0 MB 10.1 MB/s eta 0:00:00
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py): started
#   Building wheel for wikipedia (setup.py): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11785 sha256=376c34f30a0c9473441b64bd4a32f78e092175eb68aa2d085f3ec71fdc618a5c
#   Stored in directory: c:\users\harshika.pathak\appdata\local\pip\cache\wheels\5e\b6\c5\93f3dec388ae76edc830cb42901bb0232504dfc0df02fc50de
# Successfully built wikipedia
# Installing collected packages: faiss-cpu, wikipedia
#
#    ---------------------------------------- 0/2 [faiss-cpu]
#    ---------------------------------------- 0/2 [faiss-cpu]
#    ---------------------------------------- 0/2 [faiss-cpu]
#    ---------------------------------------- 0/2 [faiss-cpu]
#    ---------------------------------------- 0/2 [faiss-cpu]
#    ---------------------------------------- 0/2 [faiss-cpu]
#    ---------------------------------------- 0/2 [faiss-cpu]
#    -------------------- ------------------- 1/2 [wikipedia]
#    ---------------------------------------- 2/2 [wikipedia]
#
# Successfully installed faiss-cpu-1.11.0 wikipedia-1.4.0

# %%
from langchain_community.retrievers import WikipediaRetriever
retriever=WikipediaRetriever(top_k_results=2,lang="en")

# %%
query="the geopolitical history of india and pakistan from the perspective of a chinese"

# %%
docs=retriever.invoke(query)

# %%
for i , doc in enumerate(docs):
    print(f'\n--Result {i+1} --')
    print(f'Content:\n{doc.page_content}....')
# Out:
# --Result 1 --
# Content:
# The Dominion of Pakistan, officially Pakistan, was an independent federal dominion in the British Commonwealth of Nations, which existed from 14 August 1947 to 23 March 1956. It was created by the passing of the Indian Independence Act 1947 by the British parliament, which also created an independent Dominion of India.
# The new dominion consisted of those presidencies and provinces of British India which were allocated to it in the Partition of India. Until 1947, these regions had been ruled by the United Kingdom as a part of the British Empire.
# Its status as a federal dominion within the British Empire ended in 1956 with the completion of the Constitution of Pakistan, which established the country as a republic. The constitution also administratively split the nation into West Pakistan and East Pakistan. Until then, these provinces had been governed as a singular entity, despite being separate geographic exclaves. Eventually, the East became Bangladesh and the West became Pakistan.
# During the year that followed its independence, the new country was joined by the princely states of Pakistan, which were ruled by princes who had previously been in subsidiary alliances with the British. These states acceded to Pakistan one by one as their rulers signed Instruments of Accession. For many years, these states enjoyed a special status within the dominion and later the republic, but they were slowly incorporated into the provinces. The last remnants of their internal self-government were lost by 1974.
#
#
# == History ==
#
#
# === Partition and independence ===
#
# Section 1 of the Indian Independence Act 1947 provided that from "the fifteenth day of August, nineteen hundred and forty-seven, two independent dominions shall be set up in India, to be known respectively as India and Pakistan."  Muslims had been pushing for their own state since at least 1940 (see the Lahore resolution), believing they would become second-class citizens in a Hindu-majority India otherwise. The British monarch became the head of state of both the new dominions, with Pakistan sharing a king with the United Kingdom and the other dominions of the British Commonwealth, and the monarch's constitutional roles in Pakistan were delegated to the Governor-General of Pakistan.
# Before August 1947, about half of the area of present-day Pakistan was part of British India, which was directly governed by the British in the name of the British Crown, while the remainder were princely states in subsidiary alliances with the British, enjoying semi-autonomous self-government. The British abandoned these alliances in August 1947, leaving the states entirely independent, and between 1947 and 1948 the states all acceded to Pakistan, while retaining internal self-government for several years.
